# %%
import pandas as pd

data = pd.read_csv("/content/ss.csv")

data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("ss.csv")  # Make sure ss.csv is in your working directory

# Select only numeric columns
data_numeric = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = data_numeric.corr()

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
# Correlation Matrix:
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.990492        0.292416
# Age                       0.990492  1.000000        0.340770
# Sleep Duration            0.292416  0.340770        1.000000
# Quality of Sleep          0.427930  0.470019        0.882717
# Physical Activity Level   0.147062  0.176060        0.210458
# Stress Level             -0.390565 -0.418471       -0.810207
# Heart Rate               -0.224019 -0.224094       -0.515960
# Daily Steps               0.043494  0.057677       -0.039983
#
#                          Quality of Sleep  Physical Activity Level  \
# Person ID                        0.427930                 0.147062
# Age                              0.470019                 0.176060
# Sleep Duration                   0.882717                 0.210458
# Quality of Sleep                 1.000000                 0.190675
# Physical Activity Level          0.190675                 1.000000
# Stress Level                    -0.898239                -0.031490
# Heart Rate                      -0.659888                 0.138199
# Daily Steps                      0.016407                 0.773105
#
#                          Stress Level  Heart Rate  Daily Steps
# Person ID                   -0.390565   -0.224019     0.043494
# Age                         -0.418471   -0.224094     0.057677
# Sleep Duration              -0.810207   -0.515960    -0.039983
# Quality of Sleep            -0.898239   -0.659888     0.016407
# Physical Activity Level     -0.031490    0.138199     0.773105
# Stress Level                 1.000000    0.670010     0.187697
# Heart Rate                   0.670010    1.000000    -0.030161
# Daily Steps                  0.187697   -0.030161     1.000000
