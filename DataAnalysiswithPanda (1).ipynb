# %%
import pandas as pd

sales = pd.read_csv('/content/sample_sales_data.csv')
print(sales)
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books   1/1/2025         6  331.73
# 1   ORD0002       Edward        Books   1/2/2025         3  310.03
# 2   ORD0003        Alice     Clothing   1/3/2025         9  176.17
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 4   ORD0005       George         Home   1/5/2025         7  406.03
# ..      ...          ...          ...        ...       ...     ...
# 95  ORD0096        Diana     Clothing   4/6/2025         5  368.23
# 96  ORD0097          Bob        Books   4/7/2025         8  360.17
# 97  ORD0098        Diana     Clothing   4/8/2025         9   29.97
# 98  ORD0099        Alice         Home   4/9/2025         5  465.20
# 99  ORD0100      Charlie        Books  4/10/2025         9   41.55
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 1        930.09  Completed
# 2       1585.53   Canceled
# 3        239.91    Pending
# ...

# %%
sales[sales['TotalAmount'] > 500]
# Out:
#     OrderID CustomerName     Category OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books  1/1/2025         6  331.73
# 1   ORD0002       Edward        Books  1/2/2025         3  310.03
# 2   ORD0003        Alice     Clothing  1/3/2025         9  176.17
# 4   ORD0005       George         Home  1/5/2025         7  406.03
# 5   ORD0006      Charlie        Books  1/6/2025         9  390.27
# ..      ...          ...          ...       ...       ...     ...
# 92  ORD0093      Charlie  Electronics  4/3/2025         5  118.72
# 94  ORD0095        Alice        Books  4/5/2025         4  143.94
# 95  ORD0096        Diana     Clothing  4/6/2025         5  368.23
# 96  ORD0097          Bob        Books  4/7/2025         8  360.17
# 98  ORD0099        Alice         Home  4/9/2025         5  465.20
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 1        930.09  Completed
# 2       1585.53   Canceled
# 4       2842.21   Canceled
# 5       3512.43  Completed
# ...

# %%
sales[sales['Category'] == 'Electronics']
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 8   ORD0009      Charlie  Electronics   1/9/2025         2  222.30
# 10  ORD0011       Edward  Electronics  1/11/2025         3  398.62
# 20  ORD0021      Charlie  Electronics  1/21/2025         8  358.75
# 22  ORD0023       Hannah  Electronics  1/23/2025         8  134.65
# 35  ORD0036       Edward  Electronics   2/5/2025         4  340.00
# 41  ORD0042        Diana  Electronics  2/11/2025         9  214.39
# 46  ORD0047       Hannah  Electronics  2/16/2025         9   54.83
# 49  ORD0050       Edward  Electronics  2/19/2025         9  203.61
# 51  ORD0052        Fiona  Electronics  2/21/2025         2   55.77
# 57  ORD0058        Diana  Electronics  2/27/2025        10  161.56
# 62  ORD0063        Fiona  Electronics   3/4/2025         8  485.02
# 69  ORD0070          Bob  Electronics  3/11/2025         1  264.61
# ...

# %%
sales[(sales['Category'] == "Clothing") & (sales['Status'] == 'Completed')]
# Out:
#     OrderID CustomerName  Category  OrderDate  Quantity   Price  TotalAmount  \
# 17  ORD0018       George  Clothing  1/18/2025        10  267.14      2671.40
# 18  ORD0019        Alice  Clothing        NaN         3  227.82       683.46
# 23  ORD0024          Bob  Clothing  1/24/2025         5  293.58      1467.90
# 26  ORD0027      Charlie  Clothing  1/27/2025         3  432.17      1296.51
# 54  ORD0055          Bob  Clothing  2/24/2025         9  142.33      1280.97
# 58  ORD0059        Fiona  Clothing  2/28/2025         7  161.67      1131.69
# 66  ORD0067        Diana  Clothing   3/8/2025         3  467.02      1401.06
# 76  ORD0077        Alice  Clothing  3/18/2025         9  163.71      1473.39
# 77  ORD0078        Alice  Clothing  3/19/2025         2   25.33        50.66
# 78  ORD0079          NaN  Clothing  3/20/2025         6   80.48       482.88
# 95  ORD0096        Diana  Clothing   4/6/2025         5  368.23      1841.15
#
#        Status
# 17  Completed
# ...

# %%
sales[(sales['Quantity'] > 5) | (sales['Status'] == 'Pending')]
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books   1/1/2025         6  331.73
# 2   ORD0003        Alice     Clothing   1/3/2025         9  176.17
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 4   ORD0005       George         Home   1/5/2025         7  406.03
# 5   ORD0006      Charlie        Books   1/6/2025         9  390.27
# ..      ...          ...          ...        ...       ...     ...
# 91  ORD0092        Diana     Clothing   4/2/2025         2  172.55
# 96  ORD0097          Bob        Books   4/7/2025         8  360.17
# 97  ORD0098        Diana     Clothing   4/8/2025         9   29.97
# 98  ORD0099        Alice         Home   4/9/2025         5  465.20
# 99  ORD0100      Charlie        Books  4/10/2025         9   41.55
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 2       1585.53   Canceled
# 3        239.91    Pending
# 4       2842.21   Canceled
# ...

# %%
sales[sales['TotalAmount'].between(200,1000)]
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 1   ORD0002       Edward        Books   1/2/2025         3  310.03
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 8   ORD0009      Charlie  Electronics   1/9/2025         2  222.30
# 11  ORD0012        Alice         Home  1/12/2025         4  157.95
# 12  ORD0013        Fiona     Clothing  1/13/2025         9   44.52
# 13  ORD0014      Charlie         Home  1/14/2025         2  108.11
# 15  ORD0016       Hannah     Clothing  1/16/2025         1  241.91
# 18  ORD0019        Alice     Clothing        NaN         3  227.82
# 19  ORD0020       George     Clothing  1/20/2025         2  462.31
# 21  ORD0022        Fiona         Home  1/22/2025         9   62.70
# 31  ORD0032          Bob        Books   2/1/2025         6  149.55
# 37  ORD0038       Hannah         Home   2/7/2025         6  135.51
# 40  ORD0041       George     Clothing  2/10/2025         5  123.01
# ...

# %%
sales[sales['CustomerName'].str.startswith('A', na = False)]
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 2   ORD0003        Alice     Clothing   1/3/2025         9  176.17
# 9   ORD0010        Alice         Home  1/10/2025         3  476.14
# 11  ORD0012        Alice         Home  1/12/2025         4  157.95
# 18  ORD0019        Alice     Clothing        NaN         3  227.82
# 42  ORD0043        Alice     Clothing  2/12/2025         9   92.59
# 55  ORD0056        Alice     Clothing  2/25/2025         6  161.37
# 64  ORD0065        Alice        Books   3/6/2025         5  469.38
# 76  ORD0077        Alice     Clothing  3/18/2025         9  163.71
# 77  ORD0078        Alice     Clothing  3/19/2025         2   25.33
# 79  ORD0080        Alice     Clothing  3/21/2025         6  244.66
# 81  ORD0082        Alice         Home  3/23/2025         3  346.71
# 84  ORD0085        Alice         Home  3/26/2025         1  124.89
# 86  ORD0087        Alice  Electronics  3/28/2025         3   86.55
# ...

# %%
sales[sales['Category'].str.contains('Home')]
# Out:
#     OrderID CustomerName Category  OrderDate  Quantity   Price  TotalAmount  \
# 4   ORD0005       George     Home   1/5/2025         7  406.03      2842.21
# 9   ORD0010        Alice     Home  1/10/2025         3  476.14      1428.42
# 11  ORD0012        Alice     Home  1/12/2025         4  157.95       631.80
# 13  ORD0014      Charlie     Home  1/14/2025         2  108.11       216.22
# 14  ORD0015      Charlie     Home  1/15/2025        10  381.90      3819.00
# 21  ORD0022        Fiona     Home  1/22/2025         9   62.70       564.30
# 24  ORD0025       Edward     Home  1/25/2025        10  262.13      2621.30
# 25  ORD0026      Charlie     Home  1/26/2025         4  318.66      1274.64
# 30  ORD0031        Diana     Home  1/31/2025         2   61.32       122.64
# 32  ORD0033       Hannah     Home   2/2/2025         4  263.42      1053.68
# 37  ORD0038       Hannah     Home   2/7/2025         6  135.51       813.06
# ...

# %%
sales[sales['CustomerName'].isnull()]
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 65  ORD0066          NaN     Clothing   3/7/2025         5  190.90
# 67  ORD0068          NaN        Books   3/9/2025         8  144.79
# 73  ORD0074          NaN  Electronics  3/15/2025         1  234.80
# 78  ORD0079          NaN     Clothing  3/20/2025         6   80.48
# 83  ORD0084          NaN     Clothing        NaN         4  278.01
#
#     TotalAmount     Status
# 65       954.50    Pending
# 67      1158.32   Canceled
# 73       234.80    Pending
# 78       482.88  Completed
# 83      1112.04   Canceled

# %%
sales[sales['OrderDate'].notnull()]
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books   1/1/2025         6  331.73
# 1   ORD0002       Edward        Books   1/2/2025         3  310.03
# 2   ORD0003        Alice     Clothing   1/3/2025         9  176.17
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 4   ORD0005       George         Home   1/5/2025         7  406.03
# ..      ...          ...          ...        ...       ...     ...
# 95  ORD0096        Diana     Clothing   4/6/2025         5  368.23
# 96  ORD0097          Bob        Books   4/7/2025         8  360.17
# 97  ORD0098        Diana     Clothing   4/8/2025         9   29.97
# 98  ORD0099        Alice         Home   4/9/2025         5  465.20
# 99  ORD0100      Charlie        Books  4/10/2025         9   41.55
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 1        930.09  Completed
# 2       1585.53   Canceled
# 3        239.91    Pending
# ...

# %%
sales[sales['Status'] == 'Completed']
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 1   ORD0002       Edward        Books   1/2/2025         3  310.03
# 5   ORD0006      Charlie        Books   1/6/2025         9  390.27
# 6   ORD0007          Bob        Books   1/7/2025         7  154.19
# 11  ORD0012        Alice         Home  1/12/2025         4  157.95
# 13  ORD0014      Charlie         Home  1/14/2025         2  108.11
# 17  ORD0018       George     Clothing  1/18/2025        10  267.14
# 18  ORD0019        Alice     Clothing        NaN         3  227.82
# 22  ORD0023       Hannah  Electronics  1/23/2025         8  134.65
# 23  ORD0024          Bob     Clothing  1/24/2025         5  293.58
# 26  ORD0027      Charlie     Clothing  1/27/2025         3  432.17
# 30  ORD0031        Diana         Home  1/31/2025         2   61.32
# 31  ORD0032          Bob        Books   2/1/2025         6  149.55
# 33  ORD0034        Fiona        Books   2/3/2025         9  217.43
# ...

# %%
salescolumns = sales[['OrderID', 'CustomerName', 'TotalAmount']]
salescolumns
# Out:
#     OrderID CustomerName  TotalAmount
# 0   ORD0001       Hannah      1990.38
# 1   ORD0002       Edward       930.09
# 2   ORD0003        Alice      1585.53
# 3   ORD0004       Hannah       239.91
# 4   ORD0005       George      2842.21
# ..      ...          ...          ...
# 95  ORD0096        Diana      1841.15
# 96  ORD0097          Bob      2881.36
# 97  ORD0098        Diana       269.73
# 98  ORD0099        Alice      2326.00
# 99  ORD0100      Charlie       373.95
#
# [100 rows x 3 columns]

# %%
mask  = sales['Price'] > 100
mask
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
#       ...
# 95     True
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Price, Length: 100, dtype: bool

# %%
filter = sales[mask]
filter
# Out:
#     OrderID CustomerName     Category OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books  1/1/2025         6  331.73
# 1   ORD0002       Edward        Books  1/2/2025         3  310.03
# 2   ORD0003        Alice     Clothing  1/3/2025         9  176.17
# 4   ORD0005       George         Home  1/5/2025         7  406.03
# 5   ORD0006      Charlie        Books  1/6/2025         9  390.27
# ..      ...          ...          ...       ...       ...     ...
# 92  ORD0093      Charlie  Electronics  4/3/2025         5  118.72
# 94  ORD0095        Alice        Books  4/5/2025         4  143.94
# 95  ORD0096        Diana     Clothing  4/6/2025         5  368.23
# 96  ORD0097          Bob        Books  4/7/2025         8  360.17
# 98  ORD0099        Alice         Home  4/9/2025         5  465.20
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 1        930.09  Completed
# 2       1585.53   Canceled
# 4       2842.21   Canceled
# 5       3512.43  Completed
# ...

# %%
filtered = sales.loc[sales['TotalAmount'] > 500, ['OrderID', 'Status']]
print(filtered)
# Out:
#     OrderID     Status
# 0   ORD0001   Canceled
# 1   ORD0002  Completed
# 2   ORD0003   Canceled
# 4   ORD0005   Canceled
# 5   ORD0006  Completed
# ..      ...        ...
# 92  ORD0093  Completed
# 94  ORD0095   Canceled
# 95  ORD0096  Completed
# 96  ORD0097  Completed
# 98  ORD0099    Pending
#
# [72 rows x 2 columns]

# %%
sales.iloc[:10][['OrderID', 'TotalAmount']]
# Out:
#    OrderID  TotalAmount
# 0  ORD0001      1990.38
# 1  ORD0002       930.09
# 2  ORD0003      1585.53
# 3  ORD0004       239.91
# 4  ORD0005      2842.21
# 5  ORD0006      3512.43
# 6  ORD0007      1079.33
# 7  ORD0008      2668.60
# 8  ORD0009       444.60
# 9  ORD0010      1428.42

# %%
sales.drop(columns=['Status'], inplace = True )

# %%
filtered.to_csv("high_value_orders.csv", index=False)
